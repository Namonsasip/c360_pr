# %%
dbutils.library.installPyPI('lightgbm','2.3.1')
dbutils.library.installPyPI('plotnine','0.6.0')
dbutils.library.installPyPI('scikit-learn','0.22.2')
dbutils.library.installPyPI('seaborn','0.10.0')
dbutils.library.installPyPI('pandas','0.25.3')
dbutils.library.install('dbfs:/FileStore/jars/c8ea759c_75b4_47c3_ae04_5f122ade312e/pai-0.43.0-py3-none-any.whl')
dbutils.library.restartPython()
dbutils.library.list()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">PyPI package lightgbm has been installed already. The previously-installed package is `lightgbm==2.3.1`. To resolve this issue detach and re-attach the notebook to create a new environment or rename the package.
# PyPI package plotnine has been installed already. The previously-installed package is `plotnine==0.6.0`. To resolve this issue detach and re-attach the notebook to create a new environment or rename the package.
# ...

# %%
import os
import sys
import logging

os.environ["GITHUB_USER"] = "REPLACE ME"
os.environ["GITHUB_TOKEN"] = "REPLACE ME"

logger = spark._jvm.org.apache.log4j
logging.getLogger("py4j").setLevel(logging.ERROR)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sh mkdir -vp /home/ubuntu/projects/ && cd /home/ubuntu/projects/ 
git clone https://${GITHUB_USER}:${GITHUB_TOKEN}@github.com/quantumblack/project-samudra.git
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">mkdir: created directory &#39;/home/ubuntu/projects/&#39;
# Cloning into &#39;project-samudra&#39;...
# </div>

# %%
# %cd /home/ubuntu/projects/project-samudra
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/home/ubuntu/projects/project-samudra
# </div>

# %%
# %sh git fetch && git checkout master && git pull
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Already on &#39;master&#39;
# Your branch is up-to-date with &#39;origin/master&#39;.
# Already up-to-date.
# </div>

# %%
# %sh git branch && git status
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">* implement-dq-threshold
#   master
# On branch implement-dq-threshold
# Your branch is up-to-date with &#39;origin/implement-dq-threshold&#39;.
# nothing to commit, working directory clean
# </div>

# %%
sys.path.append(os.path.abspath("/home/ubuntu/projects/project-samudra/src"))
sys.path.append(os.path.abspath("/home/ubuntu/projects/project-samudra"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sh pip install -r /home/ubuntu/projects/project-samudra/src/requirements.txt
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Requirement already satisfied: ipython&lt;8.0,&gt;=7.0.0 in /databricks/python3/lib/python3.7/site-packages (from -r /home/ubuntu/projects/project-samudra/src/requirements.txt (line 1)) (7.4.0)
# ...
#   Using cached https://files.pythonhosted.org/packages/71/b0/471bfdb7741523dfbddd038cb5f7cc9e21d8aaa1987839af6f17238254c0/scikit_learn-0.22.2-cp37-cp37m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/63/e0/a1b39cdcb2c391f087a1538bc8a6d62a82d0439693192aef541d7b123769/pandas-0.25.3-cp37-cp37m-manylinux1_x86_64.whl
# ...

# %%
from pyspark.sql import SparkSession
def _get_spark():
  spark = SparkSession.builder.appName("data_quality_threshold_analysis").getOrCreate()
  spark.conf.set("spark.sql.sources.partitionOverwriteMode", "dynamic")
  spark.conf.set("spark.sql.parquet.binaryAsString", "true")
  spark.conf.set("spark.sql.shuffle.partitions", 1200)
  spark.conf.set("spark.sql.parquet.mergeSchema	", "true")
  spark.conf.set("spark.sql.files.maxPartitionBytes", 1024*1024*1024)
  return spark
spark = _get_spark()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sh mkdir /home/ubuntu/projects/project-samudra/conf/increment_test
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.conf.set("spark.sql.parquet.binaryAsString", "true")
spark.conf.set("spark.sql.autoBroadcastJoinThreshold",-1)
spark.conf.set("spark.sql.parquet.mergeSchema", "false")

import src.customer360.run as run
import importlib
import os

run.run_package(pipelines=['threshold_analysis_pipeline'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/botocore/vendored/requests/packages/urllib3/_collections.py:1: DeprecationWarning: Using or importing the ABCs from &#39;collections&#39; instead of from &#39;collections.abc&#39; is deprecated, and in 3.8 it will stop working
#   from collections import Mapping, MutableMapping
# `formatargspec` is deprecated since Python 3.5. Use `signature` and the `Signature` object directly
# 2020-07-03 04:46:27,072 - root - INFO - ** Kedro project project-samudra
# `name` parameter is deprecated for the `Pipeline` constructor, use `Pipeline.tag` method instead
# ...

# %%
df_threshold = spark.read.parquet("/mnt/customer360-blob-output/C360/DQ/dq_threshold_output_accuracy_and_completeness")
df_threshold_pivoted = spark.read.parquet("/mnt/customer360-blob-output/C360/DQ/dq_threshold_output_accuracy_and_completeness_pivoted")
df_threshold_grouped = spark.read.parquet("/mnt/customer360-blob-output/C360/DQ/dq_threshold_output_accuracy_and_completeness_grouped")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_threshold)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(df_threshold_pivoted)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(df_threshold_grouped)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(df_threshold_grouped)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(df_threshold_grouped)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
import pyspark.sql.functions as f
df_threshold_domain = (df_threshold_grouped.groupBy("domain").agg(
  f.sum("green_count").alias("green_count"),
  f.sum("red_count").alias("red_count")
)
  .withColumn("percent_green", f.round(f.col("green_count") / (f.col("green_count") + f.col("red_count")), 4))
  .withColumn("percent_red", f.round(f.col("red_count") / (f.col("green_count") + f.col("red_count")), 4))
)

display(df_threshold_domain)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
